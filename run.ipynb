# %%
cd /home/root1/Corenetic/code/project/tracking_with_cameara_ws
source install/setup.bash

# 启动节点（默认会显示交互窗口）
ros2 launch track_on_ros2 track_camera.launch.py \
  checkpoint_path:=/path/to/checkpoints/track_on_checkpoint.pt \
  camera_id:=0

# %%
ros2 launch track_on_ros2 track_camera_orbbec.launch.py \
checkpoint_path:=/home/root1/Corenetic/code/project/tracking_with_cameara_ws/src/track_on/checkpoints/track_on_checkpoint.pt \
camera_topic:=/camera/color/image_raw
